// %% [markdown]
// <h1 style="color:DodgerBlue">Понятие перекрытия и перегрузка методов</h1>

// %% [markdown]
// ### Перекрытие методов в C#
//
// Перекрытие методов (или переопределение) — это процесс, при котором производный класс предоставляет новую реализацию метода, уже существующего в его базовом классе. Это позволяет изменить или расширить поведение метода в производном классе без изменения исходного метода в базовом классе. Перекрытие методов является ключевой особенностью полиморфизма в объектно-ориентированном программировании.
//
// #### Пример с классами `Vehicle`, `Car` и `Motorcycle`
//
// Давайте рассмотрим пример с классами `Vehicle`, `Car` и `Motorcycle`, где каждый из этих классов имеет метод `Drive()`, который принимает параметр `speed`.
//
// ```csharp
// // Базовый класс Vehicle с виртуальным методом Drive()
// public class Vehicle
// {
//     public virtual void Drive(int speed)
//     {
//         Console.WriteLine($"Транспорт движется {speed} km/h.");
//     }
// }
//
// // Производный класс Car, переопределяющий метод Drive()
// public class Car : Vehicle
// {
//     public override void Drive(int speed)
//     {
//         Console.WriteLine($"Автомобиль движется {speed} km/h.");
//     }
// }
//
// // Производный класс Motorcycle, также переопределяющий метод Drive()
// public class Motorcycle : Vehicle
// {
//     public override void Drive(int speed)
//     {
//         Console.WriteLine($"Мотоцикл движется {speed} km/h.");
//     }
// }
// ```
//
// В этом примере, метод `Drive()` в классе `Car` и `Motorcycle` переопределяет метод `Drive()` из базового класса `Vehicle`. Это означает, что при вызове метода `Drive()` на объекте типа `Car` или `Motorcycle`, будет вызвана соответствующая реализация метода в этих классах, а не в классе `Vehicle`.
//
// #### Отличие перекрытия от перегрузки методов
//
// Перегрузка методов — это процесс определения нескольких методов с одним и тем же именем, но с разным количеством или типом параметров. Например:
//
// ```csharp
// public class ExampleClass
// {
//     public void Print(int number)
//     {
//         Console.WriteLine(number);
//     }
//
//     public void Print(double number)
//     {
//         Console.WriteLine(number.ToString());
//     }
// }
// ```
//
// В этом случае, у нас есть два метода с именем `Print`, но с разным типом параметра. Это отличается от перекрытия методов, где метод в производном классе полностью заменяет метод в базовом классе.
//
// #### Вызов методов родителя
//
// Иногда в производном классе может потребоваться вызвать метод родителя. Для этого используется ключевое слово `base`. Например, если мы хотим добавить дополнительную логику в метод `Drive()` класса `Car`, сохраняя при этом оригинальное поведение метода `Drive()` из класса `Vehicle`.
//
// ```csharp
// public class Car : Vehicle
// {
//     public override void Drive(int speed)
//     {
//         base.Drive(speed); // Вызов метода Drive() из класса Vehicle
//         Console.WriteLine("Добавляем специфическое поведение автомобиля");
//     }
// }
// ```
//
// В этом примере, после вызова `base.Drive(speed)`, выполняется дополнительная логика, специфичная для класса `Car`.
//
//
// ### Перегрузка методов в C#
//
// Перегрузка методов — это способность класса определить несколько методов с одним и тем же именем, но с разным количеством или типом параметров. Это позволяет разработчикам предоставлять различные варианты выполнения одного и того же действия в зависимости от входных данных. Перегрузка методов является одной из форм выражения полиморфизма в объектно-ориентированном программировании.
//
// #### Пример с классами `Vehicle`, `Car` и `Motorcycle`
//
// Давайте рассмотрим пример, где класс `Vehicle` содержит перегруженные методы `Drive()`, которые принимают разные типы параметров.
//
// ```csharp
// public class Vehicle
// {
//     // Метод Drive(), принимающий int
//     public void Drive(int speed)
//     {
//         Console.WriteLine($"Транспорт движется {speed} km/h.");
//     }
//
//     // Метод Drive(), принимающий string
//     public void Drive(string mode)
//     {
//         Console.WriteLine($"Автомобиль движется в {mode} режиме.");
//     }
//
//     // Метод Drive(), принимающий bool
//     public void Drive(bool isManual)
//     {
//         if (isManual)
//         {
//             Console.WriteLine("Автомобиль переключает передачи вручную.");
//         }
//         else
//         {
//             Console.WriteLine("Автомобиль оснащен автоматической коробкой передач.");
//         }
//     }
// }
// ```
//
// В этом примере класс `Vehicle` определяет три метода с именем `Drive()`, каждый из которых принимает разные типы параметров: `int`, `string` и `bool`. Это позволяет вызывать разные версии метода `Drive()` в зависимости от контекста, например:
//
// ```csharp
// Vehicle myVehicle = new Vehicle();
//
// myVehicle.Drive(60); // Вызов метода Drive() с int параметром
// myVehicle.Drive("Eco"); // Вызов метода Drive() с string параметром
// myVehicle.Drive(true); // Вызов метода Drive() с bool параметром
// ```
//
// #### Отличие перегрузки от переопределения
//
// Отличие перегрузки методов от переопределения заключается в том, что перегрузка методов включает определение нескольких методов с одним именем, но с разным набором параметров, тогда как переопределение методов (или перекрытие) означает предоставление новой реализации метода в производном классе, который уже существует в базовом классе.
//
// #### Вызов методов
//
// При вызове перегруженного метода компилятор выбирает подходящую версию метода на основе типов и количества аргументов, переданных в вызове. Если типы и количество аргументов совпадают с несколькими версиями метода, компилятор выберет ту версию, которая была объявлена первой.
//
// ### Заключение
//
// Перегрузка методов в C# позволяет классам предоставлять различные варианты выполнения одного и того же действия, адаптируясь к различным условиям использования. Это мощный инструмент для создания гибких и удобных API, позволяющих клиентам класса использовать его функциональность наиболее эффективно.
//
// Перекрытие методов в C# позволяет производным классам изменять или расширять поведение методов базовых классов, что является ключевой особенностью полиморфизма. Это отличается от перегрузки методов, которая предполагает определение нескольких методов с одинаковым именем, но с разным набором параметров.

// %% [markdown]
// <h4 style="color:DodgerBlue">Для проверки напишите пример кода на основе классов Vehicle, Car и Motorcycle ниже в блоке:</h4>
//
// ----

// %%
public class Vehicle
{
    public virtual void Drive(int speed)
    {
        Console.WriteLine($"Транспорт движется {speed} km/h.");
    }

    public void Drive(string mode)
    {
        Console.WriteLine($"Автомобиль движется в {mode} режиме.");
    }

    public void Drive(bool isManual)
    {
        if (isManual)
        {
            Console.WriteLine("Автомобиль переключает передачи вручную.");
        }
        else
        {
            Console.WriteLine("Автомобиль оснащен автоматической коробкой передач.");
        }
    }
}

public class Car : Vehicle
{
    public override void Drive(int speed)
    {
        base.Drive(speed);
        Console.WriteLine("Добавляем специфическое поведение автомобиля");
    }
}

public class Motorcycle : Vehicle
{
    public override void Drive(int speed)
    {
        Console.WriteLine($"Мотоцикл движется {speed} km/h.");
    }
}

Vehicle myVehicle = new Vehicle();

myVehicle.Drive(60);
myVehicle.Drive("Eco");
myVehicle.Drive(true);

Car myCar = new Car();

myCar.Drive(60);

Motorcycle myMotocycle = new Motorcycle();

myMotocycle.Drive(60);
// Out:
// Транспорт движется 60 km/h.
// Автомобиль движется в Eco режиме.
// Автомобиль переключает передачи вручную.
// Транспорт движется 60 km/h.
// Добавляем специфическое поведение автомобиля
// Мотоцикл движется 60 km/h.

// %% [markdown]
// <h4 style="color:Red">Задание:</h4>
//
// ----
//
// Ниже в блоке по примеру создайте базовый класс Animal и производные классы (3-4 например Dog, Cat, Bird и так далее) реализуйте структуру и объявление класса, включая свойства, геттеры и сеттеры, а также используйте перекрытия и перегрузки методов.

// %%
public class Animal
{
    private string _name;
    private int _age;
    private double _weight;
    
    public Animal()
    {
        _name = "Неизвестно";
        _age = 0;
        _weight = 0.0;
    }
    
    public Animal(string name, int age, double weight)
    {
        _name = name;
        _age = age;
        _weight = weight;
    }
    
    public string Name
    {
        get { return _name; }
        set 
        { 
            if (!string.IsNullOrWhiteSpace(value))
                _name = value;
        }
    }
    
    public int Age
    {
        get { return _age; }
        set 
        { 
            if (value >= 0)
                _age = value;
        }
    }
    
    public double Weight
    {
        get { return _weight; }
        set 
        { 
            if (value >= 0)
                _weight = value;
        }
    }
    
    public virtual void MakeSound()
    {
        Console.WriteLine("Животное издает звук.");
    }
    
    public void MakeSound(string sound)
    {
        Console.WriteLine($"{Name} издает звук: {sound}!");
    }
    
    public void MakeSound(int volume)
    {
        string loudness = volume > 5 ? "громкий" : "тихий";
        Console.WriteLine($"{Name} издает {loudness} звук.");
    }
    
    public void MakeSound(string sound, int repeatCount)
    {
        for (int i = 0; i < repeatCount; i++)
        {
            Console.WriteLine($"{Name}: {sound}!");
        }
    }
    
    public virtual void Move()
    {
        Console.WriteLine("Животное двигается.");
    }
    
    public void Move(string direction)
    {
        Console.WriteLine($"{Name} двигается в направлении: {direction}.");
    }
    
    public void Move(double speed)
    {
        Console.WriteLine($"{Name} двигается со скоростью {speed} км/ч.");
    }
    
    public void Move(string direction, double speed)
    {
        Console.WriteLine($"{Name} двигается {direction} со скоростью {speed} км/ч.");
    }
    
    public virtual void DisplayInfo()
    {
        Console.WriteLine($"Животное: {Name}, Возраст: {Age} лет, Вес: {Weight} кг");
    }
    
    public void DisplayInfo(bool showDetails)
    {
        if (showDetails)
        {
            Console.WriteLine($"=== Детальная информация ===");
            Console.WriteLine($"Имя: {Name}");
            Console.WriteLine($"Возраст: {Age} лет");
            Console.WriteLine($"Вес: {Weight} кг");
            Console.WriteLine($"Тип: {this.GetType().Name}");
        }
        else
        {
            DisplayInfo();
        }
    }
    
    public void DisplayInfo(string additionalInfo)
    {
        DisplayInfo();
        Console.WriteLine($"Дополнительно: {additionalInfo}");
    }
}

public class Dog : Animal
{
    public string Breed { get; set; }
    public bool IsTrained { get; set; }
    
    public Dog() : base()
    {
        Breed = "Неизвестно";
        IsTrained = false;
    }
    
    public Dog(string name, int age, double weight, string breed, bool isTrained) 
        : base(name, age, weight)
    {
        Breed = breed;
        IsTrained = isTrained;
    }
    
    public override void MakeSound()
    {
        Console.WriteLine($"{Name} лает: Гав-гав!");
    }
    
    public override void Move()
    {
        Console.WriteLine($"{Name} бегает и виляет хвостом.");
    }
    
    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"Порода: {Breed}, Дрессирован: {(IsTrained ? "Да" : "Нет")}");
    }
    
    public void Fetch(string item)
    {
        Console.WriteLine($"{Name} приносит {item}.");
    }
}

public class Cat : Animal
{
    public bool IsIndoor { get; set; }
    public int Lives { get; set; }
    
    public Cat() : base()
    {
        IsIndoor = true;
        Lives = 9;
    }
    
    public Cat(string name, int age, double weight, bool isIndoor, int lives) 
        : base(name, age, weight)
    {
        IsIndoor = isIndoor;
        Lives = lives;
    }
    
    public override void MakeSound()
    {
        Console.WriteLine($"{Name} мяукает: Мяу-мяу!");
    }
    
    public override void Move()
    {
        Console.WriteLine($"{Name} грациозно ходит и прыгает.");
    }
    
    public override void DisplayInfo()
    {
        base.DisplayInfo();
        string type = IsIndoor ? "домашний" : "уличный";
        Console.WriteLine($"Тип: {type} кот, Жизней: {Lives}");
    }
    
    public void Climb(string objectName)
    {
        Console.WriteLine($"{Name} залезает на {objectName}.");
    }
}

public class Bird : Animal
{
    public double Wingspan { get; set; }
    public bool CanFly { get; set; }
    
    public Bird() : base()
    {
        Wingspan = 0.0;
        CanFly = true;
    }
    
    public Bird(string name, int age, double weight, double wingspan, bool canFly) 
        : base(name, age, weight)
    {
        Wingspan = wingspan;
        CanFly = canFly;
    }
    
    public override void MakeSound()
    {
        Console.WriteLine($"{Name} поет: Чик-чирик!");
    }
    
    public override void Move()
    {
        if (CanFly)
        {
            Console.WriteLine($"{Name} летает и порхает.");
        }
        else
        {
            Console.WriteLine($"{Name} прыгает и ходит.");
        }
    }
    
    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"Размах крыльев: {Wingspan} см, Умеет летать: {(CanFly ? "Да" : "Нет")}");
    }
    
    public void BuildNest()
    {
        Console.WriteLine($"{Name} строит гнездо.");
    }
}

public class Fish : Animal
{
    public string WaterType { get; set; }
    public bool HasScales { get; set; }
    
    public Fish() : base()
    {
        WaterType = "пресная";
        HasScales = true;
    }
    
    public Fish(string name, int age, double weight, string waterType, bool hasScales) 
        : base(name, age, weight)
    {
        WaterType = waterType;
        HasScales = hasScales;
    }
    
    public override void MakeSound()
    {
        Console.WriteLine($"{Name} издает звуки: Буль-буль!");
    }
    
    public override void Move()
    {
        Console.WriteLine($"{Name} плавает в {WaterType} воде.");
    }
    
    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"Тип воды: {WaterType}, Чешуя: {(HasScales ? "Есть" : "Нет")}");
    }
    
    public void SwimDepth(double depth)
    {
        Console.WriteLine($"{Name} плавает на глубине {depth} метров.");
    }
}

        Console.WriteLine("=== Демонстрация перегрузки и переопределения методов ===\n");
        
        Animal basicAnimal = new Animal();
        Dog myDog = new Dog("Бобик", 3, 12.5, "Лабрадор", true);
        Cat myCat = new Cat("Мурка", 2, 4.2, true, 9);
        Bird myBird = new Bird("Кеша", 1, 0.3, 15.5, true);
        Fish myFish = new Fish("Немо", 1, 0.5, "морская", true);
        
        Console.WriteLine("1. Демонстрация перегрузки методов:\n");
        
        basicAnimal.Name = "Просто животное";
        basicAnimal.MakeSound();
        basicAnimal.MakeSound("Рррр");
        basicAnimal.MakeSound(7);
        basicAnimal.MakeSound("Ууу", 3);
        
        Console.WriteLine();
        basicAnimal.Move();
        basicAnimal.Move("север");
        basicAnimal.Move(25.5);
        basicAnimal.Move("запад", 10.0);
        
        Console.WriteLine();
        basicAnimal.DisplayInfo();
        basicAnimal.DisplayInfo(true);
        basicAnimal.DisplayInfo("Это тестовое животное");
        
        Console.WriteLine("\n2. Демонстрация переопределения методов:\n");
        
        List<Animal> animals = new List<Animal> { myDog, myCat, myBird, myFish };
        
        foreach (var animal in animals)
        {
            Console.WriteLine($"--- {animal.GetType().Name} ---");
            animal.DisplayInfo();
            animal.MakeSound();
            animal.Move();
            
            animal.MakeSound("специфический звук");
            animal.Move(15.0);
            Console.WriteLine();
        }
        
        Console.WriteLine("3. Демонстрация специфических методов:\n");
        
        myDog.Fetch("палку");
        myCat.Climb("дерево");
        myBird.BuildNest();
        myFish.SwimDepth(2.5);
        
        Console.WriteLine("\n4. Демонстрация полиморфизма:\n");
        
        Animal[] animalArray = new Animal[]
        {
            new Dog("Рекс", 4, 15.0, "Овчарка", true),
            new Cat("Васька", 3, 5.1, false, 7),
            new Bird("Гоша", 2, 0.4, 12.0, false),
            new Fish("Дори", 2, 0.6, "морская", true)
        };
        
        foreach (var animal in animalArray)
        {
            animal.MakeSound(); // Полиморфный вызов
        }
// Out:
// === Демонстрация перегрузки и переопределения методов ===
//
// 1. Демонстрация перегрузки методов:
//
// Животное издает звук.
// Просто животное издает звук: Рррр!
// Просто животное издает громкий звук.
// Просто животное: Ууу!
// Просто животное: Ууу!
// Просто животное: Ууу!
//
// Животное двигается.
// Просто животное двигается в направлении: север.
// Просто животное двигается со скоростью 25.5 км/ч.
// Просто животное двигается запад со скоростью 10 км/ч.
//
// Животное: Просто животное, Возраст: 0 лет, Вес: 0 кг
// === Детальная информация ===
// Имя: Просто животное
// Возраст: 0 лет
// Вес: 0 кг
// Тип: Animal
// Животное: Просто животное, Возраст: 0 лет, Вес: 0 кг
// Дополнительно: Это тестовое животное
//
// 2. Демонстрация переопределения методов:
//
// --- Dog ---
// Животное: Бобик, Возраст: 3 лет, Вес: 12.5 кг
// Порода: Лабрадор, Дрессирован: Да
// Бобик лает: Гав-гав!
// Бобик бегает и виляет хвостом.
// Бобик издает звук: специфический звук!
// Бобик двигается со скоростью 15 км/ч.
//
// --- Cat ---
// Животное: Мурка, Возраст: 2 лет, Вес: 4.2 кг
// Тип: домашний кот, Жизней: 9
// Мурка мяукает: Мяу-мяу!
// Мурка грациозно ходит и прыгает.
// Мурка издает звук: специфический звук!
// Мурка двигается со скоростью 15 км/ч.
//
// --- Bird ---
// Животное: Кеша, Возраст: 1 лет, Вес: 0.3 кг
// Размах крыльев: 15.5 см, Умеет летать: Да
// Кеша поет: Чик-чирик!
// Кеша летает и порхает.
// Кеша издает звук: специфический звук!
// Кеша двигается со скоростью 15 км/ч.
//
// --- Fish ---
// Животное: Немо, Возраст: 1 лет, Вес: 0.5 кг
// Тип воды: морская, Чешуя: Есть
// Немо издает звуки: Буль-буль!
// Немо плавает в морская воде.
// Немо издает звук: специфический звук!
// Немо двигается со скоростью 15 км/ч.
//
// 3. Демонстрация специфических методов:
//
// Бобик приносит палку.
// Мурка залезает на дерево.
// Кеша строит гнездо.
// Немо плавает на глубине 2.5 метров.
//
// 4. Демонстрация полиморфизма:
//
// Рекс лает: Гав-гав!
// Васька мяукает: Мяу-мяу!
// Гоша поет: Чик-чирик!
// Дори издает звуки: Буль-буль!
